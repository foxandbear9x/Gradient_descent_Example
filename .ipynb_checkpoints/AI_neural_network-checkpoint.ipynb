# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle

# %%
DIRECTORY = 'data'
CATEGORIES = ['without_mask', 'with_mask']

# %%
os.listdir(DIRECTORY)
# Out:
# ['without_mask', 'with_mask']

# %%
IMG_SIZE = 100

data = []

for category in CATEGORIES:
  folder = os.path.join(DIRECTORY, category)
  label = CATEGORIES.index(category)
  for img in os.listdir(folder):
    if img.find('.png') >= 0 or img.find('.jpg') >= 0:
      img_path = os.path.join(folder, img)
      img_arr = cv2.imread(img_path)
      gray = cv2.cvtColor(img_arr, cv2.COLOR_BGR2GRAY)
      if gray.size >= IMG_SIZE * IMG_SIZE:
        gray = cv2.resize(gray, (IMG_SIZE, IMG_SIZE))
        data.append([gray, label])

# %%
print('Size tập dữ liệu:', len(data))
# Out:
# Size tập dữ liệu: 3363

# %%
random.shuffle(data)

# %%
X = []
y = []

for features, labels in data:
  X.append(features)
  y.append(labels)
    
X = np.array(X)
y = np.array(y)

# %%
pickle.dump(X, open('X.pkl', 'wb'))
pickle.dump(y, open('y.pkl', 'wb'))

# %%
X = pickle.load(open('X.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# %%
def display_images(images, labels):
        plt.figure(figsize=(10,10))
        grid_size = min(25, len(images))
        for i in range(grid_size):
                plt.subplot(5, 5, i+1)
                plt.xticks([])
                plt.yticks([])
                plt.grid(False)
                plt.imshow(images[i], cmap='gray')
                plt.xlabel(CATEGORIES[labels[i]])

# %%
display_images(X_train, y_train)
plt.show()

# %%
X_train = X_train.reshape(X_train.shape[0], -1).T
y_train = y_train.reshape(1,-1)
X_test = X_test.reshape(X_test.shape[0], -1).T
y_test = y_test.reshape(1, -1)

# %%
m_train = X_train.shape[1]
m_test = X_test.shape[1]

print('Số lượng tập train:', m_train)
print('Số lượng tập test:', m_test)
print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# Số lượng tập train: 2690
# Số lượng tập test: 673
# X_train shape: (10000, 2690)
# y_train shape: (1, 2690)
# X_test shape: (10000, 673)
# y_test shape: (1, 673)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train[0]
# Out:
# array([0.49803922, 0.55294118, 0.52941176, ..., 0.73333333, 0.5372549 ,
#        0.33333333])

# %%
def sigmoid(z):
  s = 1 / (1 + np.exp(-z))
  return s

# %%
def init_weight_bias(dim):
  w = np.zeros(shape=(dim, 1))
  b = 0
  return w, b

# %%
def safe_log(X):
  result = np.where(X > 0.0000000001, X, 0)
  np.log2(result, out=result, where=result > 0)
  return result

# %%
def propagate(w, b, X, Y):
  m = X.shape[1]

  A = sigmoid(np.dot(w.T, X) + b)
  cost = (-1/m) * np.sum(Y * safe_log(A) + (1 - Y) * (safe_log(1 - A)))

  dw = (1/m) * np.dot(X, (A-Y).T)
  db = (1/m) * np.sum(A - Y)

  cost = np.squeeze(cost)
  grads = {'dw': dw, 'db': db}

  return grads, cost

# %%
def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
  costs =[]

  for i in range(num_iterations):
    grads, cost = propagate(w, b, X, Y)

    dw = grads['dw']
    db = grads['db']

    w = w - learning_rate * dw
    b = b - learning_rate * db

    if i % 100 == 0:
      costs.append(cost)

    if print_cost and i % 100 == 0:
      print('Cost after iteration %i: %f' % (i, cost))

  params = {'w': w, 'b': b}
  grads = {'dw': dw, 'db': db}

  return params, grads, costs

# %%
def predict(w, b, X):
  m = X.shape[1]

  Y_prediction = np.zeros((1, m))
  w = w.reshape(X.shape[0], 1)

  A = sigmoid(np.dot(w.T, X) + b)

  for i in range(A.shape[1]):
    Y_prediction[0, i] = 1 if A[0, i] > 0.5 else 0

  return Y_prediction

# %%
def model(X_train, Y_train, X_test, Y_test, num_iterations=2000, learning_rate=0.5, print_cost=False):

    w, b = init_weight_bias(X_train.shape[0])
    
    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    
    w = parameters['w']
    b = parameters['b']
    
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)
    
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))
    
    d = {'costs': costs,
         'Y_prediction_test': Y_prediction_test,
         'Y_prediction_train': Y_prediction_train,
         'w': w,
         'b': b,
         'learning_rate': learning_rate,
         'num_iterations': num_iterations}
    
    return d

# %%
d = model(X_train, y_train, X_test, y_test, num_iterations=2000, learning_rate=0.001, print_cost=True)
# Out:
# Cost after iteration 0: 1.000000
# Cost after iteration 100: 0.787852
# Cost after iteration 200: 0.720130
# Cost after iteration 300: 0.680463
# Cost after iteration 400: 0.652297
# Cost after iteration 500: 0.630426
# Cost after iteration 600: 0.612531
# Cost after iteration 700: 0.597374
# Cost after iteration 800: 0.584222
# Cost after iteration 900: 0.572608
# Cost after iteration 1000: 0.562214
# Cost after iteration 1100: 0.552817
# Cost after iteration 1200: 0.544251
# Cost after iteration 1300: 0.536390
# Cost after iteration 1400: 0.529135
# Cost after iteration 1500: 0.522408
# Cost after iteration 1600: 0.516144
# Cost after iteration 1700: 0.510290
# Cost after iteration 1800: 0.504801
# Cost after iteration 1900: 0.499639
# train accuracy: 88.69888475836431 %
# test accuracy: 89.15304606240713 %

# %%
costs = np.squeeze(d['costs'])
plt.plot(costs)
plt.ylabel('cost')
plt.xlabel('iterations (X 100)')
plt.title('Leaning rate = ' + str(d['learning_rate']))
plt.show()

# %%
test_image = cv2.imread(r'data\valid\5.png')

rgb_img = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)


plt.xlabel(CATEGORIES[int(result)])
plt.show()

# %%
test_image = cv2.imread(r'data\valid\5.png')
gray_test = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray_test, 1.1, 4)

if len(faces) == 0:
    l = predict_image(test_image)
else:
    for (x, y, w, h) in faces:
        faces = test_image[y:y + h, x:x + w]
        cv2.imwrite('face.jpg', faces)
        cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 0, 255), 2)
# Out:
# 1.0

# %%
def predict_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (IMG_SIZE, IMG_SIZE))
    # plt.imshow(gray_test, cmap='gray')
    gray = gray.reshape(-1, 1)
    gray = gray / 255
    label = np.squeeze(predict(d['w'], d['b'], gray))
    print(label)

# %%
predict_image(test_image)
# Out:
# 1.0

# %%
img = cv2.imread(r'data\valid\7.jpg')
  
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
  
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
  
# Draw rectangle around the faces and crop the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), 2)
    faces = img[y:y + h, x:x + w]
#     plt.imshow(faces)
    print(faces.size)
    cv2.imwrite('face.jpg', faces)
      
# Display the output
cv2.imwrite('detcted.jpg', img)
plt.imshow(img)
cv2.waitKey()
# Out:
# 634800
# -1

# %%
# !unrar x "/content/drive/MyDrive/face_mask_detector dataset.rar" "/content/drive/MyDrive/output_folder/"
# !unzip "/content/drive/MyDrive/data_moi.zip" -d "/content/drive/MyDrive/data_moi"
